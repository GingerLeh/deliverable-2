# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats

# %%
df = pd.read_csv('Walmart.csv')
df
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1  05-02-2010    1643690.90             0        42.31       2.572
# 1         1  12-02-2010    1641957.44             1        38.51       2.548
# 2         1  19-02-2010    1611968.17             0        39.93       2.514
# 3         1  26-02-2010    1409727.59             0        46.63       2.561
# 4         1  05-03-2010    1554806.68             0        46.50       2.625
# ...     ...         ...           ...           ...          ...         ...
# 6430     45  28-09-2012     713173.95             0        64.88       3.997
# 6431     45  05-10-2012     733455.07             0        64.89       3.985
# 6432     45  12-10-2012     734464.36             0        54.47       4.000
# 6433     45  19-10-2012     718125.53             0        56.47       3.969
# 6434     45  26-10-2012     760281.43             0        58.85       3.882
#
#              CPI  Unemployment
# 0     211.096358         8.106
# 1     211.242170         8.106
# 2     211.289143         8.106
# 3     211.319643         8.106
# 4     211.350143         8.106
# ...          ...           ...
# 6430  192.013558         8.684
# 6431  192.170412         8.667
# 6432  192.327265         8.667
# 6433  192.330854         8.667
# 6434  192.308899         8.667
#
# [6435 rows x 8 columns]

# %%
print(df.dtypes)
print('*'*15)
df.iloc[0]
# Out:
# Store             int64
# Date             object
# Weekly_Sales    float64
# Holiday_Flag      int64
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# dtype: object
# ***************
# Store                    1
# Date            05-02-2010
# Weekly_Sales     1643690.9
# Holiday_Flag             0
# Temperature          42.31
# Fuel_Price           2.572
# CPI             211.096358
# Unemployment         8.106
# Name: 0, dtype: object

# %%
# alterando tipo do campo data
df['Date'] = df['Date'].astype(np.datetime64)

print(df.dtypes)
print('*'*15)
df.iloc[0]
# Out:
# Store                    int64
# Date            datetime64[ns]
# Weekly_Sales           float64
# Holiday_Flag             int64
# Temperature            float64
# Fuel_Price             float64
# CPI                    float64
# Unemployment           float64
# dtype: object
# ***************
# Store                             1
# Date            2010-05-02 00:00:00
# Weekly_Sales              1643690.9
# Holiday_Flag                      0
# Temperature                   42.31
# Fuel_Price                    2.572
# CPI                      211.096358
# Unemployment                  8.106
# Name: 0, dtype: object

# %%
df.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %%
# lojas aparecem na mesma qtdade
print(df['Store'].value_counts())
# Out:
# 1     143
# 24    143
# 26    143
# 27    143
# 28    143
# 29    143
# 30    143
# 31    143
# 32    143
# 33    143
# 34    143
# 35    143
# 36    143
# 37    143
# 38    143
# 39    143
# 40    143
# 41    143
# 42    143
# 43    143
# 44    143
# 25    143
# 23    143
# 2     143
# 22    143
# 3     143
# 4     143
# 5     143
# 6     143
# 7     143
# 8     143
# 9     143
# 10    143
# 11    143
# 12    143
# 13    143
# 14    143
# 15    143
# 16    143
# 17    143
# 18    143
# 19    143
# 20    143
# 21    143
# 45    143
# Name: Store, dtype: int64

# %%
# não existe vendas com valor inferior a zero
df.loc[df['Weekly_Sales']<=0]
# Out:
# Empty DataFrame
# Columns: [Store, Date, Weekly_Sales, Holiday_Flag, Temperature, Fuel_Price, CPI, Unemployment]
# Index: []

# %%
#verificando se existe alguma data fora do esperado
df_holiday = df.loc[df['Holiday_Flag']==True]
df_holiday['Date'].unique()
# Out:
# array(['12-02-2010', '10-09-2010', '26-11-2010', '31-12-2010',
#        '11-02-2011', '09-09-2011', '25-11-2011', '30-12-2011',
#        '10-02-2012', '07-09-2012'], dtype=object)

# %%
# qtdade de vendas em dia comuns por loja
df_not_holiday = df.loc[df['Holiday_Flag']==False]
df_not_holiday['Date'].nunique()
# Out:
# 133

# %%
# qtdade de vendas em feriado por loja
df_holiday = df.loc[df['Holiday_Flag']==True]
df_holiday['Date'].nunique()
# Out:
# 10

# %%
# Criando 4 novas colunas para categorizar os feriados 

#Labor_Day
df.loc[(df['Date'] == '10-09-2010')|(df['Date'] == '09-09-2011')|(df['Date'] == '07-09-2012'),'Labor_Day'] = True
df.loc[(df['Date'] != '10-09-2010')&(df['Date'] != '09-09-2011')&(df['Date'] != '07-09-2012'),'Labor_Day'] = False

#Super_Bowl
df.loc[(df['Date'] == '12-02-2010')|(df['Date'] == '11-02-2011')|(df['Date'] == '10-02-2012'),'Super_Bowl'] = True
df.loc[(df['Date'] != '12-02-2010')&(df['Date'] != '11-02-2011')&(df['Date'] != '10-02-2012'),'Super_Bowl'] = False

#Thanksgiving
df.loc[(df['Date'] == '26-11-2010')|(df['Date'] == '25-11-2011')|(df['Date'] == '23-11-2012'),'Thanksgiving'] = True
df.loc[(df['Date'] != '26-11-2010')&(df['Date'] != '25-11-2011')&(df['Date'] != '23-11-2012'),'Thanksgiving'] = False

#Christmas
df.loc[(df['Date'] == '31-12-2010')|(df['Date'] == '30-12-2011')|(df['Date'] == '28-12-2012'),'Christmas'] = True
df.loc[(df['Date'] != '31-12-2010')&(df['Date'] != '30-12-2011')&(df['Date'] != '28-12-2012'),'Christmas'] = False

# %%
df
# Out:
#       Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0         1 2010-05-02    1643690.90             0        42.31       2.572
# 1         1 2010-12-02    1641957.44             1        38.51       2.548
# 2         1 2010-02-19    1611968.17             0        39.93       2.514
# 3         1 2010-02-26    1409727.59             0        46.63       2.561
# 4         1 2010-05-03    1554806.68             0        46.50       2.625
# ...     ...        ...           ...           ...          ...         ...
# 6430     45 2012-09-28     713173.95             0        64.88       3.997
# 6431     45 2012-05-10     733455.07             0        64.89       3.985
# 6432     45 2012-12-10     734464.36             0        54.47       4.000
# 6433     45 2012-10-19     718125.53             0        56.47       3.969
# 6434     45 2012-10-26     760281.43             0        58.85       3.882
#
#              CPI  Unemployment Labor_Day Super_Bowl Thanksgiving Christmas
# 0     211.096358         8.106     False      False        False     False
# 1     211.242170         8.106     False       True        False     False
# 2     211.289143         8.106     False      False        False     False
# 3     211.319643         8.106     False      False        False     False
# 4     211.350143         8.106     False      False        False     False
# ...          ...           ...       ...        ...          ...       ...
# 6430  192.013558         8.684     False      False        False     False
# 6431  192.170412         8.667     False      False        False     False
# 6432  192.327265         8.667     False      False        False     False
# 6433  192.330854         8.667     False      False        False     False
# 6434  192.308899         8.667     False      False        False     False
#
# [6435 rows x 12 columns]

# %%
#total por loja
df.groupby('Store')['Weekly_Sales'].sum()
# Out:
# Store
# 1     2.224028e+08
# 2     2.753824e+08
# 3     5.758674e+07
# 4     2.995440e+08
# 5     4.547569e+07
# 6     2.237561e+08
# 7     8.159828e+07
# 8     1.299512e+08
# 9     7.778922e+07
# 10    2.716177e+08
# 11    1.939628e+08
# 12    1.442872e+08
# 13    2.865177e+08
# 14    2.889999e+08
# 15    8.913368e+07
# 16    7.425243e+07
# 17    1.277821e+08
# 18    1.551147e+08
# 19    2.066349e+08
# 20    3.013978e+08
# 21    1.081179e+08
# 22    1.470756e+08
# 23    1.987506e+08
# 24    1.940160e+08
# 25    1.010612e+08
# 26    1.434164e+08
# 27    2.538559e+08
# 28    1.892637e+08
# 29    7.714155e+07
# 30    6.271689e+07
# 31    1.996139e+08
# 32    1.668192e+08
# 33    3.716022e+07
# 34    1.382498e+08
# 35    1.315207e+08
# 36    5.341221e+07
# 37    7.420274e+07
# 38    5.515963e+07
# 39    2.074455e+08
# 40    1.378703e+08
# 41    1.813419e+08
# 42    7.956575e+07
# 43    9.056544e+07
# 44    4.329309e+07
# 45    1.123953e+08
# Name: Weekly_Sales, dtype: float64

# %%
#agrupando por loja
df.groupby(['Store']).sum()
# Out:
#        Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price           CPI  \
# Store
# 1      2.224028e+08            10      9767.87     460.417  30887.555523
# 2      2.753824e+08            10      9754.94     460.417  30837.422420
# 3      5.758674e+07            10     10215.09     460.417  31372.988971
# 4      2.995440e+08            10      8902.23     460.027  18401.192733
# 5      4.547569e+07            10      9925.65     460.417  30968.878137
# 6      2.237561e+08            10      9967.10     460.417  31110.107182
# 7      8.159828e+07            10      5680.00     463.543  27693.986741
# 8      1.299512e+08            10      8939.50     460.417  31379.780750
# 9      7.778922e+07            10      9691.85     460.417  31406.616557
# 10     2.716177e+08            10     10330.49     511.357  18401.192733
# 11     1.939628e+08            10     10364.75     460.417  31372.988971
# 12     1.442872e+08            10     10047.58     515.718  18401.192733
# 13     2.865177e+08            10      7678.69     469.919  18401.192733
# 14     2.889999e+08            10      8264.11     488.718  26638.851959
# 15     8.913368e+07            10      7412.24     511.696  19318.242848
# 16     7.425243e+07            10      6439.30     463.543  27693.986741
# 17     1.277821e+08            10      6633.37     469.919  18401.192733
# 18     1.551147e+08            10      7632.09     492.169  19318.242848
# 19     2.066349e+08            10      7478.19     511.696  19318.242848
# 20     3.013978e+08            10      7929.55     488.718  29892.452680
# 21     1.081179e+08            10      9845.21     460.417  30837.422420
# 22     1.470756e+08            10      7850.29     492.169  19878.613542
# 23     1.987506e+08            10      6979.13     492.169  19318.242848
# 24     1.940160e+08            10      7726.29     511.696  19318.242848
# 25     1.010612e+08            10      7455.79     488.718  29892.452680
# 26     1.434164e+08            10      6243.13     492.169  19318.242848
# 27     2.538559e+08            10      8195.49     511.696  19878.613542
# 28     1.892637e+08            10     10047.58     515.718  18401.192733
# 29     7.714155e+07            10      7850.29     492.169  19318.242848
# 30     6.271689e+07            10      9845.21     460.417  30837.422420
# 31     1.996139e+08            10      9845.21     460.417  30837.422420
# 32     1.668192e+08            10      7542.90     463.543  27693.986741
# 33     3.716022e+07            10     10972.13     511.357  18401.192733
# 34     1.382498e+08            10      8364.91     460.027  18401.192733
# 35     1.315207e+08            10      8195.49     488.718  19878.613542
# 36     5.341221e+07            10     10175.93     458.201  30706.256907
# 37     7.420274e+07            10     10175.93     460.417  30706.256907
# 38     5.515963e+07            10     10047.58     515.718  18401.192733
# 39     2.074455e+08            10     10095.42     460.417  30706.256907
# 40     1.378703e+08            10      6817.46     492.169  19318.242848
# 41     1.813419e+08            10      6922.68     463.543  27693.986741
# 42     7.956575e+07            10     10330.49     511.357  18401.192733
# 43     9.056544e+07            10      9849.51     460.417  29706.128216
# 44     4.329309e+07            10      7678.69     469.919  18401.192733
# 45     1.123953e+08            10      8264.11     488.718  26638.851959
#
#        Unemployment
# Store
# 1          1088.290
# 2          1090.210
# 3          1026.309
# 4           852.951
# 5           900.243
# 6           944.787
# 7          1227.760
# 8           871.134
# 9           872.283
# 10         1195.904
# 11         1026.309
# 12         1875.657
# 13         1001.261
# 14         1236.771
# 15         1143.464
# 16          926.353
# 17          936.565
# 18         1263.877
# 19         1143.464
# 20         1054.112
# 21         1090.210
# 22         1153.920
# 23          685.830
# 24         1207.923
# 25         1054.112
# 26         1125.706
# 27         1144.250
# 28         1875.657
# 29         1402.313
# 30         1090.210
# 31         1090.210
# 32         1227.760
# 33         1220.241
# 34         1420.677
# 35         1256.766
# 36         1125.274
# 37         1125.274
# 38         1875.657
# 39         1125.274
# 40          685.830
# 41          997.193
# 42         1195.904
# 43         1420.677
# 44          963.194
# 45         1236.771

# %%
# total de linhas (vendas)  por loja
df.groupby('Store').size().reset_index()
# Out:
#     Store    0
# 0       1  143
# 1       2  143
# 2       3  143
# 3       4  143
# 4       5  143
# 5       6  143
# 6       7  143
# 7       8  143
# 8       9  143
# 9      10  143
# 10     11  143
# 11     12  143
# 12     13  143
# 13     14  143
# 14     15  143
# 15     16  143
# 16     17  143
# 17     18  143
# 18     19  143
# 19     20  143
# 20     21  143
# 21     22  143
# 22     23  143
# 23     24  143
# 24     25  143
# 25     26  143
# 26     27  143
# 27     28  143
# 28     29  143
# 29     30  143
# 30     31  143
# 31     32  143
# 32     33  143
# 33     34  143
# 34     35  143
# 35     36  143
# 36     37  143
# 37     38  143
# 38     39  143
# 39     40  143
# 40     41  143
# 41     42  143
# 42     43  143
# 43     44  143
# 44     45  143

# %%
# total das vendas em datas com feriado
df_holiday = df[df['Holiday_Flag'] == 1]
total_holiday = df_holiday['Weekly_Sales'].sum()

# total das vendas em datas comuns
df_notholiday = df[df['Holiday_Flag'] == 0]
total_notholiday = df_notholiday['Weekly_Sales'].sum()

print(total_holiday,  total_notholiday)
# Out:
# 505299551.56 6231919435.55

# %%
# Gráfico (lojas  X vendas ) exibindo vendas no feriado
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_holiday)

# %%
# Gráfico (lojas  X vendas ) exibindo vendas em dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_notholiday)

# %%
# total das vendas em cada feriado

#Labor_Day
df_Labor_Day = df[df['Labor_Day'] == True]
total_Labor_Day = df_Labor_Day['Weekly_Sales'].sum()

#Super_Bowl
df_Super_Bowl = df[df['Super_Bowl'] == True]
total_Super_Bowl = df_Super_Bowl['Weekly_Sales'].sum()

#Thanksgiving
df_Thanksgiving = df[df['Thanksgiving'] == True]
total_Thanksgiving = df_Thanksgiving['Weekly_Sales'].sum()

#Christmas
df_Christmas = df[df['Christmas'] == True]
total_Christmas = df_Christmas['Weekly_Sales'].sum()

print(total_Labor_Day,  total_Super_Bowl, total_Thanksgiving, total_Christmas)
# Out:
# 140727684.68 145682278.34 132414608.5 86474980.03999999

# %%
# Gráfico (lojas  X vendas ) exibindo vendas no feriado Labor Day
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_Labor_Day)

# %%
# Gráfico (lojas  X vendas ) exibindo vendas no feriado Super Bowl
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_Super_Bowl)

# %%
# Gráfico (lojas  X vendas ) exibindo vendas no feriado Thanksgiving 
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_Thanksgiving)

# %%
# Gráfico (lojas  X vendas ) exibindo vendas no feriado Christmas
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=df_Christmas)

# %%
# pegando uma amostragem de 5 vendas por loja de vendas no feriado
df_holiday.groupby('Store').apply(lambda x: x.sample(5, random_state = 225 ))
# Out:
#             Store        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# Store
# 1     99        1  30-12-2011    1497462.72             1        44.55
#       31        1  10-09-2010    1507460.69             1        78.69
#       105       1  10-02-2012    1802477.43             1        48.02
#       135       1  07-09-2012    1661767.33             1        83.96
#       53        1  11-02-2011    1649614.93             1        36.39
# ...           ...         ...           ...           ...          ...
# 45    6391     45  30-12-2011     869403.63             1        37.79
#       6323     45  10-09-2010     721460.22             1        70.87
#       6397     45  10-02-2012     803657.12             1        37.00
#       6427     45  07-09-2012     766512.66             1        75.70
#       6345     45  11-02-2011     766456.00             1        30.30
#
#             Fuel_Price         CPI  Unemployment
# Store
# 1     99         3.129  219.535990         7.866
#       31         2.565  211.495190         7.787
#       105        3.409  220.265178         7.348
#       135        3.730  222.439015         6.908
#       53         3.022  212.936705         7.742
# ...                ...         ...           ...
# 45    6391       3.389  189.062016         8.523
#       6323       2.699  182.598178         8.743
#       6397       3.640  189.707605         8.424
#       6427       3.911  191.577676         8.684
#       6345       3.239  183.701613         8.549
#
# [225 rows x 8 columns]

# %%
# pegando uma amostragem de 5 vendas por loja de vendas em dias comuns
df_notholiday.groupby('Store').apply(lambda x: x.sample(5, random_state = 225 ))
# Out:
#             Store        Date  Weekly_Sales  Holiday_Flag  Temperature  \
# Store
# 1     40        1  12-11-2010    1494479.49             0        59.61
#       39        1  05-11-2010    1551659.28             0        58.74
#       45        1  17-12-2010    1891034.93             0        49.84
#       70        1  10-06-2011    1588948.32             0        83.13
#       74        1  08-07-2011    1534849.64             0        85.83
# ...           ...         ...           ...           ...          ...
# 45    6332     45  12-11-2010     765648.93             0        46.14
#       6331     45  05-11-2010     764014.06             0        45.65
#       6337     45  17-12-2010    1123282.85             0        30.51
#       6362     45  10-06-2011     814395.17             0        73.88
#       6366     45  08-07-2011     768718.11             0        77.49
#
#             Fuel_Price         CPI  Unemployment
# Store
# 1     40         2.728  212.003944         7.838
#       39         2.689  211.956394         7.838
#       45         2.869  211.405312         7.838
#       70         3.648  215.043523         7.682
#       74         3.480  215.277175         7.962
# ...                ...         ...           ...
# 45    6332       2.931  182.991613         8.724
#       6331       2.917  182.946365         8.724
#       6337       3.140  182.517732         8.724
#       6362       3.881  185.648692         8.521
#       6366       3.711  186.032016         8.625
#
# [225 rows x 8 columns]

# %%
# lojas que mais venderam no feriado
store_holiday = (df_holiday.groupby('Store').agg({'Weekly_Sales': 'sum','Temperature':'mean', 'Fuel_Price':'mean', 'CPI':'mean', 'Unemployment':'mean'})).sort_values(by=['Weekly_Sales'],ascending=True)

# %%
# lojas que mais venderam em data comum
store_notholiday = (df_notholiday.groupby('Store').agg({'Weekly_Sales': 'sum','Temperature':'mean', 'Fuel_Price':'mean', 'CPI':'mean', 'Unemployment':'mean'})).sort_values(by=['Weekly_Sales'],ascending=False)

# %%
# Pegando o total das vendas e médias do CPI, Fuel_Priece, Unemployment por loja
stores_totais = (df_notholiday.groupby('Store').agg({'Weekly_Sales': 'sum','Temperature':'mean', 'Fuel_Price':'mean', 'CPI':'mean', 'Unemployment':'mean'})).sort_values(by=['Weekly_Sales'],ascending=False).reset_index()
stores_totais
# Out:
#     Store  Weekly_Sales  Temperature  Fuel_Price         CPI  Unemployment
# 0      20  2.789074e+08    56.242256    3.425707  209.071299      7.371489
# 1       4  2.771129e+08    63.211353    3.226481  128.694529      5.951714
# 2      14  2.677941e+08    58.561729    3.425707  186.314614      8.648571
# 3      13  2.653873e+08    54.503459    3.298180  128.694529      6.995519
# 4       2  2.545898e+08    69.025263    3.229729  215.680620      7.617120
# 5      10  2.504802e+08    72.951278    3.587008  128.694529      8.356917
# 6      27  2.349329e+08    58.030602    3.585669  139.031788      8.001895
# 7       6  2.069471e+08    70.441654    3.229729  217.587894      6.600421
# 8       1  2.057453e+08    69.087669    3.229729  216.031272      7.601722
# 9      39  1.919343e+08    71.283083    3.229729  214.763153      7.861180
# 10     19  1.908644e+08    53.015489    3.585669  135.112411      7.995759
# 11     31  1.846136e+08    69.684211    3.229729  215.680620      7.617120
# 12     23  1.841252e+08    49.659699    3.450045  135.112411      4.790098
# 13     11  1.794788e+08    73.113308    3.229729  219.426602      7.171338
# 14     24  1.792650e+08    54.802105    3.585669  135.112411      8.449624
# 15     28  1.744812e+08    71.013534    3.618256  128.694529     13.101195
# 16     41  1.679925e+08    49.254361    3.253947  193.670820      6.967068
# 17     32  1.547814e+08    53.683008    3.253947  193.670820      8.577902
# 18     18  1.434205e+08    54.137293    3.450045  135.112411      8.835323
# 19     22  1.362269e+08    55.570526    3.450045  139.031788      8.067000
# 20     12  1.329058e+08    71.013534    3.618256  128.694529     13.101195
# 21     26  1.326959e+08    44.450301    3.450045  135.112411      7.870173
# 22     34  1.278300e+08    59.341579    3.226481  128.694529      9.929677
# 23     40  1.277900e+08    48.567293    3.450045  135.112411      4.790098
# 24     35  1.207772e+08    58.030602    3.425707  139.031788      8.788053
# 25      8  1.201979e+08    63.454812    3.229729  219.474107      6.086429
# 26     17  1.179842e+08    47.350526    3.298180  128.694529      6.544105
# 27     45  1.040324e+08    58.561729    3.425707  186.314614      8.648571
# 28     21  9.985297e+07    69.684211    3.229729  215.680620      7.617120
# 29     25  9.366441e+07    52.900977    3.425707  209.071299      7.371489
# 30     43  8.420597e+07    69.682932    3.229729  207.767737      9.929677
# 31     15  8.206962e+07    52.596541    3.585669  135.112411      7.995759
# 32      7  7.487427e+07    40.588346    3.253947  193.670820      8.577902
# 33     42  7.388881e+07    72.951278    3.587008  128.694529      8.356917
# 34      9  7.189971e+07    68.657895    3.229729  219.661808      6.093489
# 35     29  7.107198e+07    55.570526    3.450045  135.112411      9.801143
# 36     37  6.912749e+07    71.850977    3.229729  214.763153      7.861180
# 37     16  6.858509e+07    45.917143    3.253947  193.670820      6.472444
# 38     30  5.834829e+07    69.684211    3.229729  215.680620      7.617120
# 39      3  5.320862e+07    72.076617    3.229729  219.426602      7.171338
# 40     38  5.134453e+07    71.013534    3.618256  128.694529     13.101195
# 41     36  4.973581e+07    71.850977    3.214248  214.763153      7.861180
# 42      5  4.188067e+07    70.152857    3.229729  216.600078      6.288241
# 43     44  4.033273e+07    54.503459    3.298180  128.694529      6.728797
# 44     33  3.453428e+07    77.440827    3.587008  128.694529      8.525850

# %%
# Gráfico (lojas  X vendas ) exibindo as vendas totais em Feriados e dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Weekly_Sales', data=stores_totais)

# %%
# Gráfico (lojas  X pci ) exibindo vendas totais em Feriados e dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='CPI', data=stores_totais)

# %%
# Gráfico (lojas  X Unemployment ) exibindo vendas totais em Feriados e dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Unemployment', data=stores_totais)

# %%
# Gráfico (lojas  X Fuel_Price ) exibindo vendas totais em Feriados e dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Fuel_Price', data=stores_totais)

# %%
# Gráfico (lojas  X Temperature ) exibindo vendas totais em Feriados e dias comuns
plt.figure(figsize=(15,5))
sns.barplot(x='Store', y='Temperature', data=stores_totais)
